# %%
# !pip install --upgrade sagemaker
# !pip install torch==1.9.1
# !pip install torchvision==0.10.1
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for sagemaker did not run successfully.
#   │ exit code: 1
#   ╰─> [1041 lines of output]
#       C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3568.0_x64__qbz5n2kfra8p0\lib\site-packages\setuptools\dist.py:717: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#         warnings.warn(
#       running install
#       running build
#       running build_py
#       creating build
#       creating build\lib
#       creating build\lib\sagemaker
#       copying src\sagemaker\accept_types.py -> build\lib\sagemaker
#       copying src\sagemaker\algorithm.py -> build\lib\sagemaker
#       copying src\sagemaker\analytics.py -> build\lib\sagemaker
#       copying src\sagemaker\base_deserializers.py -> build\lib\sagemaker
#       copying src\sagemaker\base_predictor.py -> build\lib\sagemaker
# ...

# %%
from inference import model_fn

model_path = "./"
model = model_fn(model_path)
model
# Out:
# RecursiveScriptModule(
#   original_name=Plant_Disease_Model2
#   (network): RecursiveScriptModule(
#     original_name=ResNet
#     (conv1): RecursiveScriptModule(original_name=Conv2d)
#     (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#     (relu): RecursiveScriptModule(original_name=ReLU)
#     (maxpool): RecursiveScriptModule(original_name=MaxPool2d)
#     (layer1): RecursiveScriptModule(
#       original_name=Sequential
#       (0): RecursiveScriptModule(
#         original_name=BasicBlock
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
#         (bn1): RecursiveScriptModule(original_name=BatchNorm2d)
#         (relu): RecursiveScriptModule(original_name=ReLU)
#         (conv2): RecursiveScriptModule(original_name=Conv2d)
#         (bn2): RecursiveScriptModule(original_name=BatchNorm2d)
#       )
#       (1): RecursiveScriptModule(
#         original_name=BasicBlock
#         (conv1): RecursiveScriptModule(original_name=Conv2d)
# ...

# %%
! tar -czvf model.tar.gz model_directory
# Out:
# tar: model_directory: Cannot stat: No such file or directory
# tar: Exiting with failure status due to previous errors
